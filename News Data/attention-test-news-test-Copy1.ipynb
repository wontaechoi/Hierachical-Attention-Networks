# %%
import os
import re
import time
from keras import regularizers
import keras
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from keras import backend as K
from keras.models import Model
from keras import initializers
from keras.engine.topology import Layer
from keras.layers import Dense, Input, RepeatVector, Permute, Multiply, Lambda,BatchNormalization
from keras.layers import Embedding, GRU, Bidirectional, TimeDistributed, LSTM, Dropout
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.utils.np_utils import to_categorical
from nltk import tokenize
import tensorflow as tf
from gensim.models import Word2Vec
from keras.preprocessing.sequence import pad_sequences
from konlpy.tag import Kkma, Okt
from sklearn.model_selection import train_test_split
import kss
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sn
import sentencepiece as spm
from keras.callbacks import EarlyStopping
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Hierachcial Attention Layer

# %%
class Attention(Layer):
    def __init__(self, regularizer = None, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.regularizer = regularizer
        self.supports_masking = True

    def build(self, input_shape):
        self.context = self.add_weight(name='context', shape=(input_shape[-1], 1),initializer=initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None),regularizer=self.regularizer,trainable=True)
        super(Attention, self).build(input_shape)
    def compute_mask(self, inputs, mask=None):
        return None

    def call(self, x, mask=None):
        attention_in = K.exp(K.squeeze(K.dot(x, self.context), axis=-1))
        attention = attention_in/K.expand_dims(K.sum(attention_in, axis=-1), -1)

        if mask is not None:
        # use only the inputs specified by the mask
        # import pdb; pdb.set_trace()
            attention = attention*K.cast(mask, 'float32')

        weighted_sum = K.batch_dot(K.permute_dimensions(x, [0, 2, 1]), attention)
        return weighted_sum

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[-1]

# %%
! nvidia-smi
# Out:
# Wed Aug 12 08:44:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.37                 Driver Version: 396.37                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:3B:00.0 Off |                    0 |
# | N/A   33C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-PCIE...  Off  | 00000000:D8:00.0 Off |                    0 |
# | N/A   27C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %% [markdown]
# ### 뉴스 데이터 불러오기

# %%
news_data = pd.read_csv('Article_unity.csv', encoding = 'cp949')

# %%
news_data.columns = ['date', 'category', 'publisher','title', 'content']

# %%
news_data
# Out:
#             date category    publisher  \
# 0       20190101     IT과학         전자신문
# 1       20190101     IT과학  ZDNet Korea
# 2       20190101     IT과학        아시아경제
# 3       20190101     IT과학         서울신문
# 4       20190101     IT과학         이데일리
# 5       20190101     IT과학         동아일보
# 6       20190101     IT과학  ZDNet Korea
# 7       20190101     IT과학         서울신문
# 8       20190101     IT과학         한국경제
# 9       20190101     IT과학         한국경제
# 10      20190101     IT과학         한국경제
# 11      20190101     IT과학         한국경제
# 12      20190101     IT과학         한국경제
# 13      20190101     IT과학         한국경제
# 14      20190101     IT과학         한국경제
# 15      20190101     IT과학         서울신문
# 16      20190101     IT과학       디지털데일리
# 17      20190101     IT과학       디지털데일리
# 18      20190101     IT과학       디지털타임스
# 19      20190101     IT과학       디지털타임스
# 20      20190101     IT과학       디지털타임스
# 21      20190101     IT과학       디지털타임스
# 22      20190101     IT과학       디지털타임스
# 23      20190101     IT과학       디지털타임스
# 24      20190101     IT과학       디지털타임스
# 25      20190101     IT과학       디지털타임스
# 26      20190101     IT과학         한국일보
# 27      20190101     IT과학          한겨레
# 28      20190101     IT과학          한겨레
# 29      20190101     IT과학       파이낸셜뉴스
# ...          ...      ...          ...
# 444415  20190123       세계          SBS
# 444416  20190123       세계          뉴스1
# 444417  20190123       세계          뉴스1
# 444418  20190123       세계         연합뉴스
# 444419  20190123       세계        헤럴드경제
# 444420  20190123       세계          KBS
# 444421  20190123       세계          KBS
# 444422  20190123       세계         이데일리
# 444423  20190123       세계          뉴시스
# 444424  20190123       세계          KBS
# 444425  20190123       세계          KBS
# 444426  20190123       세계         연합뉴스
# 444427  20190123       세계         전자신문
# 444428  20190123       세계       아이뉴스24
# 444429  20190123       세계          KBS
# 444430  20190123       세계          KBS
# 444431  20190123       세계          뉴시스
# 444432  20190123       세계          뉴시스
# 444433  20190123       세계          뉴시스
# 444434  20190123       세계          뉴시스
# 444435  20190123       세계          뉴스1
# 444436  20190123       세계          뉴시스
# 444437  20190123       세계          뉴시스
# 444438  20190123       세계          뉴시스
# 444439  20190123       세계          뉴시스
# 444440  20190123       세계          뉴시스
# 444441  20190123       세계          뉴시스
# 444442  20190123       세계          뉴시스
# 444443  20190123       세계          뉴시스
# 444444  20190123       세계          YTN
#
#                                             title  \
# 0               NIPA AI융합본부 신설 등 신SW산업 육성 조직개편 단행
# 1                    멜론·지니 음원가격 인상...권리자 권익 향상 목적
# 2               창작자몫 저작권료 5% 오르자 음원서비스 이용료 30% 인상
# 3         고든 정의 TECH 2019년 CPU 시장을 보는 세 가지 관전 포인트
# 4                     포토강성주 본부장 새해 우편물 소통현장 밤샘 방문
# 5          인류 최초 지구에서 가장 먼 곳까지 날아간 무인탐사선 ‘뉴호라이즌스’
# 6                           여기어때 사용자 이메일 주소 노출 사고
# 7            아하 우주 오시리스렉스 소행성 ‘베누’ 500m 앞까지 접근 성공
# 8       2019년 이 기술들을 주목하라…자율주행車가 배송하고 AI가 경리업무 전담
# 9                      가격 올린 멜론·지니뮤직 할인 상품으로 고객몰이
# 10                  SKT 5G로 보신각 타종 생중계…“시차 1초 이내”
# 11                       올 CES…LG 중저가폰 삼성 갤럭시홈 뜬다
# 12                  LG유플러스 예능·키즈 등 IPTV 채널 37개 추가
# 13            스타트업 브리핑 여행 앱 ‘트리플’ 가입자 300만 명 돌파 등
# 14                        생활 속 불만 모아 브랜드 불편지수 만들죠
# 15             와우 과학 철통 보안이라던 ‘정맥 인증’ ‘밀랍 손’이 뚫었다
# 16           신년기획5G③ 5G 융합서비스 활성화 법제도정립·선도사업 선행돼야
# 17                NIPA 조직개편...AI·블록체인 등 신산업 조직 신설
# 18                     물갈이 인사·고용 갈등… 내우외환 시달린 과기계
# 19                        글로벌 고객 모셔라… 팔 걷은 바이오 투톱
# 20                     빗썸도 국가공인보안인증… 양극화되는 거래소 보안
# 21           “서비스 중단” vs “기구 참여 우선”… 계속되는 ‘카풀 갈등’
# 22               한국형 구글稅 공정경쟁 첫발… 새해 줄줄이 역차별해소 기대
# 23                        저작권료 인상따라 음원이용료 일제히 오른다
# 24                         모든 연령대 他국가보다 4차산업혁명 늦다
# 25                        해외 불법복제물 전담 저작권침해대응단 출범
# 26                               제야의 종 5G 생방송 탔어요
# 27                  음원값 일제히 인상…다운로드 결합상품 인상폭 커
# 28                           5G 이동통신으로 방송 생중계 성공
# 29                         뱅드림 걸즈 밴드 파티 덕심 사로 잡았다
# ...                                           ...
# 444415         북미 합숙 담판 北 최선희 귀국길 경유지 베이징 침묵 속 도착
# 444416                        기자회견 마치고 떠나는 푸틴과 아베
# 444417                      크렘린 정상회담장으로 가는 푸틴과 아베
# 444418                     무역전쟁 후폭풍…中 첨단산업 생산도 암운
# 444419                  역대 최장 ‘셧다운’ 끝낼 ‘6가지 시나리오’
# 444420                       루마니아 하르기타서 개썰매 대회 열려
# 444421                         태국 몽족의 나무 수레 경주 대회
# 444422                  美셧다운 끝낼 수 있는 6가지 시나리오 CNN
# 444423           일본은행 단기금리 0.1% 장기금리 0% 금융완화 유지종합
# 444424                      일본 최신 기술 도입해 회의 문화 변화
# 444425                  타이완 가오슝 호화 유람선으로 지역 경제 부흥
# 444426          일본은행 기준금리 0.1% 동결…올 물가상승률 전망 하향종합
# 444427                   폭스콘 아이폰 생산 공장 中→인도로 이전하나
# 444428                           MS 크롬북 대항마 대거 공개
# 444429             러시아 시위대 “쿠릴 섬 일본 반환 반대”…결론은 못내
# 444430             미국 상공회의소 ‘中 제조 2025’ 비판…중국 압박용
# 444431                         다보스 포럼서 발언하는 빌 게이츠
# 444432                             앨고어 다보스 포럼서 연설
# 444433                     다보스 포럼서 연설하는 앨고어 전 부통령
# 444434                              포럼 경청하는 빌 게이츠
# 444435                    무료급식소 셰프의 설명듣는 펠로시 하원의장
# 444436              영화 로마 작품상 등 아카데미 10개 부문 후보 올라
# 444437                    영화 로마 아카데미 10개 부문 후보 올라
# 444438                 영화 로마 2019 아카데미 10개 부문 후보에
# 444439                     LA 교사 파업 궁극적으로 학생 위한 것
# 444440                LA 교사 파업 잠정 타결…교사들 학교로 돌아가나
# 444441                LA 교사 파업 잠정 타결로 교육 현장 복귀 조짐
# 444442                      입추의 여지 없는 LA 교사 시위 현장
# 444443                             LA 교사 파업 잠정 타결
# 444444       취재N팩트 유전자 편집 中 과학자 대학서 해임...형사 처벌 수순
#
#                                                   content
# 0       정보통신산업진흥원 원장 김창용·NIPA 은 AI융합산업본부와 ICT생태계본부 싱크탱...
# 1       저작권 징수규정 개정안 적용...신규가입자 대상 지디넷코리아 안희정 기자 멜론과 지...
# 2       멜론·벅스·지니 등 일제히 가격 인상… 원가 인상에 따른 것 아시아경제 이민우 기자...
# 3       서울신문 나우뉴스 올해 서버 시장에 출시될 2세대 64코어 에픽 프로세서를 공개하는...
# 4       이데일리 김현아 기자 강성주 우정사업본부장 오른쪽 이 새해 1월1일 0시부터 우편물...
# 5       사진 동아DB 미국항공우주국 NASA 의 무인탐사선 ‘뉴호라이즌스’ New Hori...
# 6       개인정보 이용내역 통지 과정서 발생...KISA에 신고 지디넷코리아 백봉삼 기자 위...
# 7       서울신문 나우뉴스 오시리스 렉스가 베누와 80km 떨어진 거리에서 촬영한 사진 NA...
# 8       주요 외신·시장조사업체 선정 DNA 활용한 음악 추천 등 개인화 서비스 한 단계 발...
# 9       저작권료 인상 따른 충격 완화 스트리밍 이용료는 대부분 동결 김주완 기자 음원 서비...
# 10      SK텔레콤은 5세대 5G 이동통신망과 생중계 솔루션을 활용해 1일 0시 서울 종로 ...
# 11      8일 美 라스베이거스에서 개막 갤럭시S10·폴더블폰 등 기대작 은 MWC 전후 공개...
# 12      U tv 전체 채널 수 237개로 김태훈 기자 LG유플러스는 인터넷TV IPTV 서...
# 13      여행 앱 ‘트리플’ 가입자 300만 명 돌파 해외여행 정보 앱 응용프로그램 ‘트리플...
# 14      스타트업 리포트 불편 공유 앱 불편함 개발 김준영 닛픽 대표 불편 수집가 프로불편러...
# 15      서울신문 나우뉴스 정맥 인증 보안을 해제한 ‘밀랍 손’ 정맥 인증 보안을 해제한 ‘...
# 16      작년 12월1일 한국은 세계 최초 5세대 5G 이동통신을 상용화했다. 5G는 초고속...
# 17      1실 3단 5본부 36팀으로 개편 디지털데일리 홍하나기자 정보통신산업진흥원 원장 김...
# 18      정부 과기정책 퇴보 우려 과학기술계는 지난 2018년 한해동안 큰 내우외환 을 겪으...
# 19      김태한 삼성바이오로직스 사장 CDMO 사업현황·비전 등 소개 제3공장 물량 수주에 ...
# 20      의무대상 거래소 빅4 ISMS 인증 소비자 쏠림으로 해커표적될수도 대다수 거래소 인...
# 21      전현희 더불어민주당 택시·카풀 TF 위원장 맨 왼쪽 과 김정렬 국토교통부 2차관 두...
# 22      정교한 설계·실효적 단속 미흡땐 국내 인터넷기업만 더 옥죌 수도 인터넷규제 역차별 ...
# 23      묶음상품 할인율도 50%→40% 멜론·지니뮤직 등 잇따라 공지 1일부터 창작자 몫인...
# 24      응답자 52.2% 현정부 대응 느려 48.9%는 인재양성 가장 시급 신년특집 신산업...
# 25      방송통신심의위원회는 국내 문화콘텐츠산업을 보호하기 위해 해외에 서버를 두고 웹툰 등...
# 26      SK텔레콤 5G TV 생중계 세계 최초 성공 1일 서울 종로구 보신각에서 XtvN ...
# 27      음원사용료 징수규정 바뀐 탓 스트리밍 요금은 거의 동결 스마트폰 등을 통해 음악을 ...
# 28      SKT 스마트폰·5G 망 통해 보신각 타종 ‘XtvN’서 생중계 “유선 생방송과 동...
# 29      서울 코믹월드 부스 성료 뱅드림 걸즈 밴드 파티 서울코믹월드 부스에 이용자가 포토월...
# ...                                                   ...
# 444415  스웨덴에서 2차 북미 정상회담을 위한 실무협상을 했던 최선희 북한 외무성 부상이 오...
# 444416  모스크바 AFP 뉴스1 우동명 기자 블라디미르 푸틴 러시아 대통령과 아베 신조 일본...
# 444417  모스크바 AFP 뉴스1 우동명 기자 블라디미르 푸틴 러시아 대통령과 아베 신조 일본...
# 444418  지난달 산업용 로봇 생산 전년 동월비 12.1% 급감 생산기지 해외이전 우려 …정부...
# 444419  CNN ‘셧다운 종식’ 6가지 방안 제시 온건파 공화당 상원의원들의 반발 국가비상사...
# 444420  동화 속 같은 겨울 풍광을 자랑하는 루마니아 중북부 산악지대 하르기타입니다. 이곳에...
# 444421  태국 북부 파야오 지역. 이곳 산악 지역에 소수 민족인 몽족이 살고 있습니다. 원래...
# 444422  공화당·민주당 셧다운 종료 정반대 법안 추진 정치 생명 위협 느끼면 돌아서는 의원 ...
# 444423  물가전망 2019년 1.4%→0.9% 2020년도 1.5%→1..4%로 낮춰 세계 ...
# 444424  앵커 일본에서는 다양한 최신 기술 덕분에 회의 모습이 변하고 있습니다. 리포트 도쿄...
# 444425  앵커 타이완 가오슝시가 호화 유람선을 늘려 지역 경제을 부흥시키겠다고 나섰습니다. ...
# 444426  금융완화 정책 유지…올 물가상승률 전망 1.4%→0.9%로 도쿄 연합뉴스 김정선 특...
# 444427  월스트리트저널 WSJ 은 애플 최대 협력업체인 대만 폭스콘이 아이폰 생산 공장을 인...
# 444428  교육시장 겨냥 189달러 노트북…디지털 펜도 내놔 아이뉴스24 안희권 기자 마이크로...
# 444429  앵커 러일 정상이 모스크바에서 쿠릴 열도의 섬 반환 등 현안을 놓고 회담을 가졌지만...
# 444430  앵커 미국 상공회의소가 중국의 첨단 제조업 육성책 중국제조 2025 를 비판적으로 ...
# 444431  다보스 AP 뉴시스 22일 현지시간 스위스 다보스에서 열린 세계 경제 포럼 WEF ...
# 444432  다보스 AP 뉴시스 22일 현지시간 스위스 다보스에서 열린 세계 경제 포럼 WEF ...
# 444433  다보스 AP 뉴시스 22일 현지시간 스위스 다보스에서 열린 세계 경제 포럼 WEF ...
# 444434  다보스 AP 뉴시스 22일 현지시간 스위스 다보스에서 열린 세계 경제 포럼 WEF ...
# 444435  워싱턴 AFP 뉴스1 우동명 기자 낸시 펠로시 미국 하원의장이 22일 현지시간 비영...
# 444436  로마수르 AP 뉴시스 22일 현지시간 알폰소 쿠아론 감독의 영화 로마 가 2019 ...
# 444437  로마수르 AP 뉴시스 22일 현지시간 알폰소 쿠아론 감독의 영화 로마 가 2019 ...
# 444438  로마수르 AP 뉴시스 22일 현지시간 알폰소 쿠아론 감독의 영화 로마 가 2019 ...
# 444439  로스앤젤레스 AP 뉴시스 22일 현지시간 LA 지역 교사들이 에벌린 초등학교 앞에서...
# 444440  로스앤젤레스 AP 뉴시스 22일 현지시간 LA 지역 교사들이 에벌린 초등학교 앞에서...
# 444441  로스앤젤레스 AP 뉴시스 22일 현지시간 LA 지역 연합 교사들이 LA 시청 건물이...
# 444442  로스앤젤레스 AP 뉴시스 22일 현지시간 LA 지역 연합 교사들이 LA 시청 건물이...
# 444443  로스앤젤레스 AP 뉴시스 22일 현지시간 LA 지역 교사들의 시위를 지지하는 부모와...
# 444444  앵커 세계 최초로 유전자 편집 기술을 이용해 여자 쌍둥이를 탄생시켜 윤리성 논란을 ...
#
# [444445 rows x 5 columns]

# %% [markdown]
# ### 타이틀과 기사 본문 합치기

# %%
def title_content_combine(title,content):
    return str(title) + ' ' + str(content)

# %%
news_data['x'] = news_data.apply(lambda x : title_content_combine(x.title, x.content), axis = 1)

# %%
data = news_data[['x', 'category']]

# %% [markdown]
# ### 문자 카테고리 숫자화

# %%
def category_to_number(y_data):
    category_list = list(set(y_data.category))
    new_y = []
    for i, category in enumerate(y_data.category):
        new_y.append(category_list.index(category))
    ret = pd.DataFrame(new_y)
    ret.columns = ['category']
    return ret,category_list

# %%
x_train  = pd.DataFrame(data.x)

# %%
y_train = pd.DataFrame(data.category)
y_train.columns = ['category']

# %%
y_train,category_list = category_to_number(y_train)
y_train = to_categorical(np.asarray(y_train))

# %%
stop_words = []
with open("한국어불용어100.txt", 'r',encoding='utf-8') as f:
    for line in f.read().split('\n'):
        stop_words.append(line.split('\t')[0])

# %%
contents = []
texts = []
not_splitted = []
for i, text in enumerate(x_train.x):
    if i % 10000 == 0:
        print(i)
    sentences =kss.split_sentences(text)
    for sen in sentences:
        texts.append(sen)
    contents.append(sentences)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000

# %%
with open('spm_news_sw.txt', 'w', encoding='utf-8') as f:
    for sent in texts:
        f.write('{}\n'.format(sent))
    f.close()

# %%
sp = spm.SentencePieceProcessor()

# %%
sp.load('news_vocab_sw.model')
# Out:
# True

# %%
MAX_SENTENCES = 15
MAX_SENTENCE_LENGTH = 100
result = []
X_train = np.zeros((x_train.shape[0], MAX_SENTENCES, MAX_SENTENCE_LENGTH), dtype='int32')
for i, sentences in enumerate(contents):
    for j, sent in enumerate(sentences):
        if j < MAX_SENTENCES:
            result.append(sp.EncodeAsPieces(sent))
            wordTokens = sp.EncodeAsIds(sent)
            sen = sp.EncodeAsPieces(sent)
            for k in range(len(wordTokens)):
                if k< MAX_SENTENCE_LENGTH:
                    if sen[k] in stop_words:
                        X_train[i][j][k] = 0
                    else:
                        X_train[i][j][k] = wordTokens[k]

# %%
data.groupby('category').count()
# Out:
#               x
# category
# IT과학      69663
# 경제        67174
# 사회        67421
# 생활문화      74368
# 세계        23530
# 오피니언      70355
# 정치        71934

# %%
validation_split = 0.2
nb_validation_samples = int(validation_split * X_train.shape[0])

# %%
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
X = X_train[indices]
Y = y_train[indices]

# %%
nb_test_samples = int(nb_validation_samples * 0.25)

# %%
x_train = X[:-nb_validation_samples]
y_train = Y[:-nb_validation_samples]
x_val = X[-nb_validation_samples:-nb_test_samples]
y_val = Y[-nb_validation_samples:-nb_test_samples]
x_test =X[-nb_test_samples:]
y_test = Y[-nb_test_samples:]

# %%
len(x_train), len(x_val), len(x_test),len(y_train), len(y_val), len(y_test)
# Out:
# (355556, 66667, 22222, 355556, 66667, 22222)

# %%
embedding_dim = 200

# %% [markdown]
# ### 사용하는 뉴스 데이터를 이용하여 w2v 모델 생성

# %%
w2v_model = Word2Vec(result, size=embedding_dim, window=5, min_count=5,  sg=1, iter= 5)

# %%
#w2v_model.save('news_w2v.model')

# %%
w2v_model = Word2Vec.load('news_w2v.model')

# %%
with open('news_vocab_sw.vocab', encoding='utf-8') as f:
    Vo = [doc.strip().split("\t") for doc in f]
    
word2idx = {w[0]: i for i, w in enumerate(Vo)}

# %%
word_index = list(word2idx.keys())
len(word_index)
# Out:
# 300000

# %%
def get_vector(word, word2vec_model):
    if word in word2vec_model:
        return word2vec_model[word]
    else:
        return None

# %%
def get_embedding_matrix(word_index, embedding_dim, w2v_model,word2idx):
    embedding_matrix = np.zeros((len(list(word_index))+1, embedding_dim))
    for i, word in enumerate(list(word2idx.keys())):
        temp = get_vector(word, w2v_model)

        if temp is not None:
            embedding_matrix[i] = temp
    return embedding_matrix

# %%
embm = get_embedding_matrix(word_index, embedding_dim, w2v_model,word2idx)
# Out:
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#
# /home/bigdata/.conda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Attention 모델 생성 (함수화 할 필요 있음)

# %%
def create_model(MAX_SENTENCES, MAX_SENTENCE_LENGTH, word_index, embedding_matrix):
    l2_reg = regularizers.l2(1e-8)

    sentence_in = Input(shape=(MAX_SENTENCE_LENGTH,), dtype='int32')
    embedded_word_seq = Embedding(len(word_index) +1,embedding_dim, weights=[embedding_matrix], input_length = MAX_SENTENCE_LENGTH, trainable= True, mask_zero=True, name='word_embeddings',)(sentence_in)
    word_encoder = Bidirectional(GRU(50, return_sequences=True, kernel_regularizer=l2_reg))(embedded_word_seq)
    dense_transform_w = Dense(100, activation='relu', name='dense_transform_w', kernel_regularizer=l2_reg)(word_encoder)
    attention_weighted_sentence = Model(sentence_in, Attention(name='word_attention', regularizer=l2_reg)(dense_transform_w))
    word_attention_model = attention_weighted_sentence


    texts_in = Input(shape=(MAX_SENTENCES, MAX_SENTENCE_LENGTH), dtype='int32')
    attention_weighted_sentences = TimeDistributed(attention_weighted_sentence)(texts_in)
    sentence_encoder = Bidirectional(GRU(50, return_sequences=True, kernel_regularizer=l2_reg))(attention_weighted_sentences)
    dense_transform_s = Dense(100, activation='relu', name='dense_transform_s',kernel_regularizer=l2_reg)(sentence_encoder)
    attention_weighted_text = Attention(name='sentence_attention', regularizer=l2_reg)(dense_transform_s)
    attention_weighted_text1 = Dropout(100)(attention_weighted_text)
    prediction = Dense(y_train.shape[1], activation='softmax')(attention_weighted_text1)
    model = Model(texts_in, prediction)

    model.compile(optimizer=keras.optimizers.Adam(lr=0.001),loss='categorical_crossentropy',metrics=['acc'])
    
    return model, word_attention_model

# %%
model1, word_attention_model1 = create_model(MAX_SENTENCES, MAX_SENTENCE_LENGTH, word_index, embedding_matrix)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 15, 100)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 15, 100)           60085700
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 15, 100)           45300
# _________________________________________________________________
# dense_transform_s (Dense)    (None, 15, 100)           10100
# _________________________________________________________________
# sentence_attention (Attentio (None, 100)               100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 707
# =================================================================
# Total params: 60,141,907
# Trainable params: 60,141,907
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor = 'val_loss')


hist = model.fit(x=[x_train],
          y=[y_train],
          batch_size=512,
          epochs=5,
          shuffle=True,
          callbacks=[es],
          validation_data=([x_val], 
                           [y_val]))
# Out:
# Train on 355556 samples, validate on 66667 samples
# Epoch 1/5
# 355556/355556 [==============================] - 397s 1ms/step - loss: 0.5864 - acc: 0.7892 - val_loss: 0.3878 - val_acc: 0.8583
# Epoch 2/5
# 355556/355556 [==============================] - 387s 1ms/step - loss: 0.2916 - acc: 0.8870 - val_loss: 0.3483 - val_acc: 0.8654
# Epoch 3/5
# 122880/355556 [=========>....................] - ETA: 3:59 - loss: 0.1919 - acc: 0.9184
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0fe82e661876> in <module>
#       9           callbacks=[es],
#      10           validation_data=([x_val],
# ---> 11                            [y_val]))
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 모델 predict
# #### 테스트 셋 결과 확인

# %%
prd = model.predict(x_test).argsort()

# %%
tst = y_test.argsort()

# %%
count = 0
length = len(y_test)
for i in range(length):
    if prd[i][-1] == tst[i][-1]:
        count+=1
count/length
# Out:
# 0.8545585455854559

# %% [markdown]
# ### Attention weight 시각화 코드

# %%
def normalize(text):
    reviews = []
    texts = []
    return kss.split_sentences(text) 

def encode_input(reviews):
    
    
    
    ret = np.zeros((MAX_SENTENCES, MAX_SENTENCE_LENGTH), dtype='int32')
    for j, sent in enumerate(reviews):
        if j < MAX_SENTENCES:
            wordTokens = sp.EncodeAsIds(sent)
            for k in range(len(wordTokens)):
                if k< MAX_SENTENCE_LENGTH:
                    ret[j][k] = wordTokens[k]
            
    return ret

# %%
def get_activation_maps(data, num, word_attention_model):
    normalized_text = normalize(data.x[num])
    encoded_text = encode_input(normalized_text)

    hidden_word_encoding_out = Model(inputs=word_attention_model.input,outputs=word_attention_model.get_layer('dense_transform_w').output)
    hidden_word_encodings = hidden_word_encoding_out.predict(encoded_text)
    word_context = word_attention_model.get_layer('word_attention').get_weights()[0]
    u_wattention = encoded_text*np.exp(np.squeeze(np.dot(hidden_word_encodings, word_context)))





    nopad_encoded_text = encoded_text[-len(text):]
    nopad_encoded_text = [list(filter(lambda x: x > 0, sentence)) for sentence in nopad_encoded_text]


    reconstructed_texts = [[sp.DecodeIds([int(i)]) for i in sentence] for sentence in nopad_encoded_text]
    nopad_wattention = u_wattention[:len(normalized_text)]
    nopad_wattention = nopad_wattention/np.expand_dims(np.sum(nopad_wattention, -1), -1)
    nopad_wattention = np.array([attention_seq[:len(sentence)] for attention_seq, sentence in zip(nopad_wattention, nopad_encoded_text)])
    word_activation_maps = []


    for i, att in enumerate(nopad_wattention):
        word_activation_maps.append(list(zip(reconstructed_texts[i], att)))

    hidden_sentence_encoding_out = Model(inputs=model.input, outputs=model.get_layer('dense_transform_s').output)
    hidden_sentence_encodings = np.squeeze(hidden_sentence_encoding_out.predict(np.expand_dims(encoded_text, 0)), 0)
    sentence_context = model.get_layer('sentence_attention').get_weights()[0]
    u_sattention = np.exp(np.squeeze(np.dot(hidden_sentence_encodings, sentence_context), -1))
    nopad_sattention = u_sattention[-len(normalized_text):]

    nopad_sattention = nopad_sattention/np.expand_dims(np.sum(nopad_sattention, -1), -1)

    return list(zip(word_activation_maps, nopad_sattention))

# %% [markdown]
# 결과 체크를 위해 랜덤 데이터 추출

# %%
import random
rnd = random.randint(0, data.shape[0])
rnd
# Out:
# 108967

# %%
am = get_activation_maps(data, rnd,  word_attention_model)
am
# Out:
# [([('ET', 0.09583434347389568),
#    ('투자뉴스', 0.2824348374771326),
#    ('SK', 0.0021115712670261304),
#    ('네트웍스', 0.007248049345483853),
#    ('2019', 4.893261000564e-06),
#    ('년', 5.275965419920034e-07),
#    ('성장사업', 0.061779558575751965),
#    ('...', 4.568190230167512e-06),
#    ('BUY', 0.013530385019845268),
#    ('삼성증권', 0.10266466793558415),
#    ('삼성증권', 0.033584444657849225),
#    ('에서', 4.643414737150925e-06),
#    ('10', 1.4525018235353817e-05),
#    ('일', 3.72589270552257e-07),
#    ('SK', 2.0335640582279926e-05),
#    ('네트웍스', 0.0057101018705161604),
#    ('0017', 0.3459419458457621),
#    ('40', 0.0008943208578242334),
#    ('에', 1.134962544585712e-06),
#    ('대해', 1.1294560204287656e-06),
#    ('2019', 2.911720089722113e-06),
#    ('년', 1.9639532150245513e-07),
#    ('성장사업', 0.01025200757127669),
#    ('의', 1.6711197104609935e-08),
#    ('긍정적', 2.220454183749732e-05),
#    ('변화에', 3.001408473483319e-05),
#    ('주목', 0.00018370824549264535),
#    ('라며', 5.695455758057189e-05),
#    ('투자의견', 0.0010581846334942837),
#    ('을', 4.564512769184804e-08),
#    ('BUY', 0.006080703102080645),
#    ('로', 2.396504398993151e-05),
#    ('제시하였', 0.010068995319364739),
#    ('고', 4.258160221839355e-07),
#    ('아울러', 0.00017940327486323064),
#    ('목표주가로', 0.019832695196229662),
#    ('는', 6.681589827368407e-08),
#    ('6', 1.2651790383655379e-06),
#    ('400', 0.00014088815107150512),
#    ('원을', 0.0001757960312322293),
#    ('내놓았다', 0.00010319254823035518),
#    ('.', 2.9599919658205336e-09)],
#   0.20611347),
#  ([('삼성증권', 0.1509802544697928),
#    ('백', 0.0011807485715940225),
#    ('재승', 0.07858889664339279),
#    ('김', 2.1547302300379986e-05),
#    ('슬', 0.2656467454004018),
#    ('애널리스트', 0.010950652198238518),
#    ('가', 2.7264530901833567e-06),
#    ('동종목', 0.28596586339285285),
#    ('에', 1.741821130041728e-06),
#    ('대하여', 0.0028755334620430687),
#    ('이번에', 0.0009472674087020804),
#    ('제시한', 0.0008034268257159367),
#    ('BUY', 0.020588148899501665),
#    ('의견은', 0.006308343803716444),
#    ('삼성증권', 0.038543570782534085),
#    ('의', 1.1411400145759596e-06),
#    ('직전', 0.0006746557662786716),
#    ('매매의견', 0.007256043501559708),
#    ('에서', 1.0735972134111849e-06),
#    ('큰', 5.92453848765151e-06),
#    ('변화없이', 0.01298006829381913),
#    ('그대로', 2.0548077184437763e-05),
#    ('유지되는', 0.004097395939662039),
#    ('것이고', 3.1829929160248846e-05),
#    ('작년', 2.0020070913784097e-05),
#    ('연말', 0.0007542558078710287),
#    ('의', 2.7424940532137576e-07),
#    ('시장컨센서스', 0.09808160916566669),
#    ('에', 2.0596723135789124e-07),
#    ('비추어', 0.011726320863269222),
#    ('보면', 1.191112145247993e-05),
#    ('매수', 6.72441774509878e-05),
#    ('의견이', 8.726354552969509e-05),
#    ('계속', 1.4323328853011455e-05),
#    ('유지되', 0.000674696890781281),
#    ('고', 2.571877616106175e-07),
#    ('있는', 2.2936043280520293e-07),
#    ('상태이다', 8.723493720385888e-05),
#    ('.', 5.107790395871258e-09)],
#   0.20149182),
#  ([('그리고', 0.0016903268707433134),
#    ('최근', 0.00014533019590605732),
#    ('', 2.4816899759683984e-06),
#    ('분기내', 0.6677800415675903),
#    ('발표된', 0.003335351860342301),
#    ('전체', 0.00017424123058607695),
#    ('증권사', 0.012360771939696645),
#    ('리포트', 0.0005279872735319542),
#    ('의', 5.862203915034598e-07),
#    ('컨센서스와', 0.00888126659139021),
#    ('비교', 6.50410090753741e-05),
#    ('를', 6.479358944788771e-08),
#    ('해볼', 0.0020885633070641682),
#    ('경우에', 0.00035180216568451024),
#    ('오늘', 9.547447122901504e-06),
#    ('발표된', 0.0011298309327037305),
#    ('투자의견', 0.008645936403045828),
#    ('은', 1.31719999004105e-06),
#    ('전체의견', 0.1818080872071713),
#    ('에', 9.755312646991536e-07),
#    ('수렴하고', 0.02615465535472026),
#    ('있어', 2.196588492088344e-05),
#    ('이번', 2.9783571748628974e-05),
#    ('의견은', 0.005806473957023749),
#    ('시장의', 0.0012471065745425372),
#    ('평균', 0.00039423452614039897),
#    ('적인', 0.0001309600820073167),
#    ('기대감이', 0.0561212504157992),
#    ('객관적으로', 0.00846302358685804),
#    ('표현된', 0.011022041871008513),
#    ('것으로', 1.5479413348325578e-06),
#    ('분석', 0.0003198371367419076),
#    ('되고', 0.0012864796280180155),
#    ('있다', 9.42244769099452e-07),
#    ('.', 1.4578750032182974e-07)],
#   0.19881065),
#  ([('목표주가', 0.1212298573918356),
#    ('의', 9.19422572537176e-06),
#    ('추이', 0.020959960379214836),
#    ('를', 1.066351291417896e-05),
#    ('살펴보면', 0.050026810138030994),
#    ('정체구간', 0.5627804637021785),
#    ('을', 6.005785967793146e-07),
#    ('한동안', 0.00714732924162581),
#    ('보낸', 0.0012383062385017522),
#    ('후에', 0.0021806394828177513),
#    ('최근', 7.689841684569585e-05),
#    ('2', 3.2052987741734487e-06),
#    ('회', 0.00021827348190990757),
#    ('연속', 0.0005618185924920575),
#    ('목표가', 0.013607320947313659),
#    ('가', 1.753362750958897e-06),
#    ('높아졌는데', 0.1246885694815102),
#    ('이번에', 0.0029353795613410627),
#    ('조정된', 0.022455010574733095),
#    ('상승폭', 0.004478526754877252),
#    ('은', 1.0212652159032175e-06),
#    ('이전보다', 0.009340831207850285),
#    ('다소', 0.007242060064140903),
#    ('둔화된', 0.04793099720696663),
#    ('모습이다', 0.0008744156948840813),
#    ('.', 9.319695259240821e-08)],
#   0.19689643),
#  ([('또한', 0.019660995993214813),
#    ('전일', 0.009644191818622404),
#    ('종가', 0.09597169928740934),
#    ('기준으로', 0.013147395034731538),
#    ('볼때', 0.17098643178767398),
#    ('동종목의', 0.15156845477259362),
#    ('현주가', 0.11162916629987583),
#    ('는', 3.142682966721009e-06),
#    ('이번에', 0.01578398753433692),
#    ('제시된', 0.13621645499329504),
#    ('목표가', 0.01931872192951997),
#    ('대비', 0.000498071024137973),
#    ('11.5%', 0.10774225354515975),
#    ('의', 4.2543741838886785e-06),
#    ('저평가', 0.05359326419322126),
#    ('요인이', 0.008656515585497421),
#    ('존재한다는', 0.05251633243335903),
#    ('해석이', 0.007852468971669451),
#    ('제시되고', 0.02520574735973885),
#    ('있다', 3.4827515540512807e-07),
#    ('.', 1.0210363681599881e-07)],
#   0.1966877)]

# %%
activation_map
# Out:
# [([('ET', 0.09583434347389568),
#    ('투자뉴스', 0.2824348374771326),
#    ('SK', 0.0021115712670261304),
#    ('네트웍스', 0.007248049345483853),
#    ('2019', 4.893261000564e-06),
#    ('년', 5.275965419920034e-07),
#    ('성장사업', 0.061779558575751965),
#    ('...', 4.568190230167512e-06),
#    ('BUY', 0.013530385019845268),
#    ('삼성증권', 0.10266466793558415),
#    ('삼성증권', 0.033584444657849225),
#    ('에서', 4.643414737150925e-06),
#    ('10', 1.4525018235353817e-05),
#    ('일', 3.72589270552257e-07),
#    ('SK', 2.0335640582279926e-05),
#    ('네트웍스', 0.0057101018705161604),
#    ('0017', 0.3459419458457621),
#    ('40', 0.0008943208578242334),
#    ('에', 1.134962544585712e-06),
#    ('대해', 1.1294560204287656e-06),
#    ('2019', 2.911720089722113e-06),
#    ('년', 1.9639532150245513e-07),
#    ('성장사업', 0.01025200757127669),
#    ('의', 1.6711197104609935e-08),
#    ('긍정적', 2.220454183749732e-05),
#    ('변화에', 3.001408473483319e-05),
#    ('주목', 0.00018370824549264535),
#    ('라며', 5.695455758057189e-05),
#    ('투자의견', 0.0010581846334942837),
#    ('을', 4.564512769184804e-08),
#    ('BUY', 0.006080703102080645),
#    ('로', 2.396504398993151e-05),
#    ('제시하였', 0.010068995319364739),
#    ('고', 4.258160221839355e-07),
#    ('아울러', 0.00017940327486323064),
#    ('목표주가로', 0.019832695196229662),
#    ('는', 6.681589827368407e-08),
#    ('6', 1.2651790383655379e-06),
#    ('400', 0.00014088815107150512),
#    ('원을', 0.0001757960312322293),
#    ('내놓았다', 0.00010319254823035518),
#    ('.', 2.9599919658205336e-09)],
#   0.20611347),
#  ([('삼성증권', 0.1509802544697928),
#    ('백', 0.0011807485715940225),
#    ('재승', 0.07858889664339279),
#    ('김', 2.1547302300379986e-05),
#    ('슬', 0.2656467454004018),
#    ('애널리스트', 0.010950652198238518),
#    ('가', 2.7264530901833567e-06),
#    ('동종목', 0.28596586339285285),
#    ('에', 1.741821130041728e-06),
#    ('대하여', 0.0028755334620430687),
#    ('이번에', 0.0009472674087020804),
#    ('제시한', 0.0008034268257159367),
#    ('BUY', 0.020588148899501665),
#    ('의견은', 0.006308343803716444),
#    ('삼성증권', 0.038543570782534085),
#    ('의', 1.1411400145759596e-06),
#    ('직전', 0.0006746557662786716),
#    ('매매의견', 0.007256043501559708),
#    ('에서', 1.0735972134111849e-06),
#    ('큰', 5.92453848765151e-06),
#    ('변화없이', 0.01298006829381913),
#    ('그대로', 2.0548077184437763e-05),
#    ('유지되는', 0.004097395939662039),
#    ('것이고', 3.1829929160248846e-05),
#    ('작년', 2.0020070913784097e-05),
#    ('연말', 0.0007542558078710287),
#    ('의', 2.7424940532137576e-07),
#    ('시장컨센서스', 0.09808160916566669),
#    ('에', 2.0596723135789124e-07),
#    ('비추어', 0.011726320863269222),
#    ('보면', 1.191112145247993e-05),
#    ('매수', 6.72441774509878e-05),
#    ('의견이', 8.726354552969509e-05),
#    ('계속', 1.4323328853011455e-05),
#    ('유지되', 0.000674696890781281),
#    ('고', 2.571877616106175e-07),
#    ('있는', 2.2936043280520293e-07),
#    ('상태이다', 8.723493720385888e-05),
#    ('.', 5.107790395871258e-09)],
#   0.20149182),
#  ([('그리고', 0.0016903268707433134),
#    ('최근', 0.00014533019590605732),
#    ('', 2.4816899759683984e-06),
#    ('분기내', 0.6677800415675903),
#    ('발표된', 0.003335351860342301),
#    ('전체', 0.00017424123058607695),
#    ('증권사', 0.012360771939696645),
#    ('리포트', 0.0005279872735319542),
#    ('의', 5.862203915034598e-07),
#    ('컨센서스와', 0.00888126659139021),
#    ('비교', 6.50410090753741e-05),
#    ('를', 6.479358944788771e-08),
#    ('해볼', 0.0020885633070641682),
#    ('경우에', 0.00035180216568451024),
#    ('오늘', 9.547447122901504e-06),
#    ('발표된', 0.0011298309327037305),
#    ('투자의견', 0.008645936403045828),
#    ('은', 1.31719999004105e-06),
#    ('전체의견', 0.1818080872071713),
#    ('에', 9.755312646991536e-07),
#    ('수렴하고', 0.02615465535472026),
#    ('있어', 2.196588492088344e-05),
#    ('이번', 2.9783571748628974e-05),
#    ('의견은', 0.005806473957023749),
#    ('시장의', 0.0012471065745425372),
#    ('평균', 0.00039423452614039897),
#    ('적인', 0.0001309600820073167),
#    ('기대감이', 0.0561212504157992),
#    ('객관적으로', 0.00846302358685804),
#    ('표현된', 0.011022041871008513),
#    ('것으로', 1.5479413348325578e-06),
#    ('분석', 0.0003198371367419076),
#    ('되고', 0.0012864796280180155),
#    ('있다', 9.42244769099452e-07),
#    ('.', 1.4578750032182974e-07)],
#   0.19881065),
#  ([('목표주가', 0.1212298573918356),
#    ('의', 9.19422572537176e-06),
#    ('추이', 0.020959960379214836),
#    ('를', 1.066351291417896e-05),
#    ('살펴보면', 0.050026810138030994),
#    ('정체구간', 0.5627804637021785),
#    ('을', 6.005785967793146e-07),
#    ('한동안', 0.00714732924162581),
#    ('보낸', 0.0012383062385017522),
#    ('후에', 0.0021806394828177513),
#    ('최근', 7.689841684569585e-05),
#    ('2', 3.2052987741734487e-06),
#    ('회', 0.00021827348190990757),
#    ('연속', 0.0005618185924920575),
#    ('목표가', 0.013607320947313659),
#    ('가', 1.753362750958897e-06),
#    ('높아졌는데', 0.1246885694815102),
#    ('이번에', 0.0029353795613410627),
#    ('조정된', 0.022455010574733095),
#    ('상승폭', 0.004478526754877252),
#    ('은', 1.0212652159032175e-06),
#    ('이전보다', 0.009340831207850285),
#    ('다소', 0.007242060064140903),
#    ('둔화된', 0.04793099720696663),
#    ('모습이다', 0.0008744156948840813),
#    ('.', 9.319695259240821e-08)],
#   0.19689643),
#  ([('또한', 0.019660995993214813),
#    ('전일', 0.009644191818622404),
#    ('종가', 0.09597169928740934),
#    ('기준으로', 0.013147395034731538),
#    ('볼때', 0.17098643178767398),
#    ('동종목의', 0.15156845477259362),
#    ('현주가', 0.11162916629987583),
#    ('는', 3.142682966721009e-06),
#    ('이번에', 0.01578398753433692),
#    ('제시된', 0.13621645499329504),
#    ('목표가', 0.01931872192951997),
#    ('대비', 0.000498071024137973),
#    ('11.5%', 0.10774225354515975),
#    ('의', 4.2543741838886785e-06),
#    ('저평가', 0.05359326419322126),
#    ('요인이', 0.008656515585497421),
#    ('존재한다는', 0.05251633243335903),
#    ('해석이', 0.007852468971669451),
#    ('제시되고', 0.02520574735973885),
#    ('있다', 3.4827515540512807e-07),
#    ('.', 1.0210363681599881e-07)],
#   0.1966877)]

# %%
data.x[rnd]
# Out:
# 'ET투자뉴스SK네트웍스 2019년 성장사업… BUY삼성증권 삼성증권에서 10일 SK네트웍스 001740 에 대해 2019년 성장사업의 긍정적 변화에 주목 라며 투자의견을 BUY 로 제시하였고 아울러 목표주가로는 6 400원을 내놓았다. 삼성증권 백재승 김슬 애널리스트가 동종목에 대하여 이번에 제시한 BUY 의견은 삼성증권의 직전 매매의견에서 큰 변화없이 그대로 유지되는 것이고 작년 연말의 시장컨센서스에 비추어 보면 매수 의견이 계속 유지되고 있는 상태이다. 그리고 최근 분기내 발표된 전체 증권사 리포트의 컨센서스와 비교를 해볼 경우에 오늘 발표된 투자의견은 전체의견에 수렴하고 있어 이번 의견은 시장의 평균적인 기대감이 객관적으로 표현된 것으로 분석되고 있다. 목표주가의 추이를 살펴보면 정체구간을 한동안 보낸 후에 최근 2회 연속 목표가가 높아졌는데 이번에 조정된 상승폭은 이전보다 다소 둔화된 모습이다. 또한 전일 종가 기준으로 볼때 동종목의 현주가는 이번에 제시된 목표가 대비 11.5%의 저평가 요인이 존재한다는 해석이 제시되고 있다.'

# %% [markdown]
# ### sentence attention이 가장 높았던 문장 추출

# %% [markdown]
# ### 가장 attention weight이 높았던 문장 중 word attention weight이 높았던 단어 추출

# %%
def extract_sentence_and_word(activation_map, words_num, normalized_text):
    max_sentence_weight = 0
    max_sentence_index = -1
    for i, sentence in enumerate(activation_map):
        if sentence[1] > max_sentence_weight:
            max_sentence_weight = sentence[1]
            max_sentence_index= i
    mx_sent = activation_map[max_sentence_index][0]
    mx_sent.sort(key= lambda x: x[1],reverse=True)
    return normalized_text[max_sentence_index], mx_sent[:words_num]

# %%
extract_sentence_and_word(activation_map, 3, normalized_text)
# Out:
# ('ET투자뉴스SK네트웍스 2019년 성장사업… BUY삼성증권 삼성증권에서 10일 SK네트웍스 001740 에 대해 2019년 성장사업의 긍정적 변화에 주목 라며 투자의견을 BUY 로 제시하였고 아울러 목표주가로는 6 400원을 내놓았다.',
#  [('0017', 0.3459419458457621),
#   ('투자뉴스', 0.2824348374771326),
#   ('삼성증권', 0.10266466793558415)])

# %% [markdown]
# ### 모델 예측 카테고리 값 확인

# %%
ans = model.predict(np.reshape(encoded_text, (1,)+encoded_text.shape))

# %%
print("predicted: {}\n  answer:{}".format(category_list[ans.argsort()[0][-1]],category_list[category_list.index(data.category[rnd])]))
# Out:
# predicted: 경제
#   answer:경제

# %%
import pickle
with open('catelist.pickle', 'wb') as f:
    pickle.dump(category_list, f)
